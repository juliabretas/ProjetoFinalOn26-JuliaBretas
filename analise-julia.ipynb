# %% [markdown]
# ### Consulta, tratamento e limpeza dos dados

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_music_mh = pd.read_csv('mxmh_survey_results.csv')
df_music_mh
# Out:
#                Timestamp   Age Primary streaming service  Hours per day  \
# 0     8/27/2022 19:29:02  18.0                   Spotify            3.0
# 1     8/27/2022 19:57:31  63.0                   Pandora            1.5
# 2     8/27/2022 21:28:18  18.0                   Spotify            4.0
# 3     8/27/2022 21:40:40  61.0             YouTube Music            2.5
# 4     8/27/2022 21:54:47  18.0                   Spotify            4.0
# ..                   ...   ...                       ...            ...
# 731  10/30/2022 14:37:28  17.0                   Spotify            2.0
# 732   11/1/2022 22:26:42  18.0                   Spotify            1.0
# 733   11/3/2022 23:24:38  19.0   Other streaming service            6.0
# 734   11/4/2022 17:31:47  19.0                   Spotify            5.0
# 735    11/9/2022 1:55:20  29.0             YouTube Music            2.0
#
#     While working Instrumentalist Composer         Fav genre Exploratory  \
# ...

# %%
df_music_mh.shape
# Out:
# (736, 33)

# %%
df_music_mh.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 736 entries, 0 to 735
# Data columns (total 33 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Timestamp                     736 non-null    object
#  1   Age                           735 non-null    float64
#  2   Primary streaming service     735 non-null    object
#  3   Hours per day                 736 non-null    float64
#  4   While working                 733 non-null    object
#  5   Instrumentalist               732 non-null    object
#  6   Composer                      735 non-null    object
#  7   Fav genre                     736 non-null    object
#  8   Exploratory                   736 non-null    object
#  9   Foreign languages             732 non-null    object
#  10  BPM                           629 non-null    float64
#  11  Frequency [Classical]         736 non-null    object
# ...

# %%
df_music_mh.dtypes
# Out:
# Timestamp                        object
# Age                             float64
# Primary streaming service        object
# Hours per day                   float64
# While working                    object
# Instrumentalist                  object
# Composer                         object
# Fav genre                        object
# Exploratory                      object
# Foreign languages                object
# BPM                             float64
# Frequency [Classical]            object
# Frequency [Country]              object
# Frequency [EDM]                  object
# Frequency [Folk]                 object
# Frequency [Gospel]               object
# Frequency [Hip hop]              object
# Frequency [Jazz]                 object
# Frequency [K pop]                object
# Frequency [Latin]                object
# Frequency [Lofi]                 object
# Frequency [Metal]                object
# Frequency [Pop]                  object
# ...

# %%
df_music_mh.columns
# Out:
# Index(['Timestamp', 'Age', 'Primary streaming service', 'Hours per day',
#        'While working', 'Instrumentalist', 'Composer', 'Fav genre',
#        'Exploratory', 'Foreign languages', 'BPM', 'Frequency [Classical]',
#        'Frequency [Country]', 'Frequency [EDM]', 'Frequency [Folk]',
#        'Frequency [Gospel]', 'Frequency [Hip hop]', 'Frequency [Jazz]',
#        'Frequency [K pop]', 'Frequency [Latin]', 'Frequency [Lofi]',
#        'Frequency [Metal]', 'Frequency [Pop]', 'Frequency [R&B]',
#        'Frequency [Rap]', 'Frequency [Rock]', 'Frequency [Video game music]',
#        'Anxiety', 'Depression', 'Insomnia', 'OCD', 'Music effects',
#        'Permissions'],
#       dtype='object')

# %%
df_music_mh.drop_duplicates()
df_music_mh.shape
# Out:
# (736, 33)

# %%
columns_drop = ['Timestamp','Instrumentalist','Composer','Permissions']
df_music_mh = df_music_mh.drop(columns_drop, axis=1)
df_music_mh
# Out:
#       Age Primary streaming service  Hours per day While working  \
# 0    18.0                   Spotify            3.0           Yes
# 1    63.0                   Pandora            1.5           Yes
# 2    18.0                   Spotify            4.0            No
# 3    61.0             YouTube Music            2.5           Yes
# 4    18.0                   Spotify            4.0           Yes
# ..    ...                       ...            ...           ...
# 731  17.0                   Spotify            2.0           Yes
# 732  18.0                   Spotify            1.0           Yes
# 733  19.0   Other streaming service            6.0           Yes
# 734  19.0                   Spotify            5.0           Yes
# 735  29.0             YouTube Music            2.0           Yes
#
#             Fav genre Exploratory Foreign languages    BPM  \
# 0               Latin         Yes               Yes  156.0
# 1                Rock         Yes                No  119.0
# ...

# %%
columns_drop = ['Frequency [Classical]','Frequency [Country]','Frequency [EDM]','Frequency [Folk]','Frequency [Gospel]','Frequency [Hip hop]','Frequency [Jazz]','Frequency [K pop]','Frequency [Latin]','Frequency [Lofi]','Frequency [Metal]','Frequency [Pop]','Frequency [R&B]','Frequency [Rap]', 'Frequency [Rock]', 'Frequency [Video game music]']
df_music_mh = df_music_mh.drop(columns_drop, axis=1)
df_music_mh
# Out:
#       Age Primary streaming service  Hours per day While working  \
# 0    18.0                   Spotify            3.0           Yes
# 1    63.0                   Pandora            1.5           Yes
# 2    18.0                   Spotify            4.0            No
# 3    61.0             YouTube Music            2.5           Yes
# 4    18.0                   Spotify            4.0           Yes
# ..    ...                       ...            ...           ...
# 731  17.0                   Spotify            2.0           Yes
# 732  18.0                   Spotify            1.0           Yes
# 733  19.0   Other streaming service            6.0           Yes
# 734  19.0                   Spotify            5.0           Yes
# 735  29.0             YouTube Music            2.0           Yes
#
#             Fav genre Exploratory Foreign languages    BPM  Anxiety  \
# 0               Latin         Yes               Yes  156.0      3.0
# ...

# %%
traducoes = {
    'Age': 'Idade' ,
    'Primary streaming service': 'Principal streaming usado',
    'Hours per day': 'Horas por dia',
    'While working': 'Durante o trabalho',
    'Fav genre': 'Gênero preferido',
    'Exploratory': 'Explorando',
    'Foreign languages': 'Musicas internacionais',
    'BPM': 'BPM',
    'Anxiety': 'Ansiedade',
    'Depression': 'Depressão',
    'Insomnia': 'Insônia',
    'OCD': 'TOC',
    'Music effects': 'Efeito da Música'
 }

novas_colunas = []

for chave, valor in traducoes.items():
    novas_colunas.append(valor)
novas_colunas
# Out:
# ['Idade',
#  'Principal streaming usado',
#  'Horas por dia',
#  'Durante o trabalho',
#  'Gênero preferido',
#  'Explorando',
#  'Musicas internacionais',
#  'BPM',
#  'Ansiedade',
#  'Depressão',
#  'Insônia',
#  'TOC',
#  'Efeito da Música']

# %%
#sinceramente não sei o que fazer com essa informação
df_music_mh.isnull().sum()
# Out:
# Age                            1
# Primary streaming service      1
# Hours per day                  0
# While working                  3
# Fav genre                      0
# Exploratory                    0
# Foreign languages              4
# BPM                          107
# Anxiety                        0
# Depression                     0
# Insomnia                       0
# OCD                            0
# Music effects                  8
# dtype: int64

# %% [markdown]
# ## INSIGHTS
# * Qual o tipo de musica mais e menos preferido?
# * Quais as percepções dessas pessoas sobre os efeitos que a musica os causa?
# *

# %% [markdown]
# ## Analisando os dados

# %%
df_music_mh['Age'].value_counts()
# Out:
# Age
# 18.0    85
# 19.0    61
# 17.0    59
# 21.0    52
# 16.0    44
#         ..
# 39.0     1
# 73.0     1
# 72.0     1
# 69.0     1
# 89.0     1
# Name: count, Length: 61, dtype: int64

# %%
qtd_bmp = df_music_mh['BPM'].value_counts()
qtd_bmp
# Out:
# BPM
# 120.0    45
# 140.0    25
# 150.0    18
# 110.0    16
# 105.0    15
#          ..
# 181.0     1
# 106.0     1
# 191.0     1
# 40.0      1
# 168.0     1
# Name: count, Length: 135, dtype: int64

# %%
df_genero_mais_popular = df_music_mh['Fav genre'].value_counts()
df_genero_mais_popular
# Out:
# Fav genre
# Rock                188
# Pop                 114
# Metal                88
# Classical            53
# Video game music     44
# EDM                  37
# R&B                  35
# Hip hop              35
# Folk                 30
# K pop                26
# Country              25
# Rap                  22
# Jazz                 20
# Lofi                 10
# Gospel                6
# Latin                 3
# Name: count, dtype: int64

# %%
qtd_bmp = df_music_mh['Music effects'].value_counts()
qtd_bmp
# Out:
# Music effects
# Improve      542
# No effect    169
# Worsen        17
# Name: count, dtype: int64

# %%
df_music_mh.describe(include='all').T
# Out:
#                            count unique      top freq            mean  \
# Age                        735.0    NaN      NaN  NaN       25.206803
# Primary streaming service    735      6  Spotify  458             NaN
# Hours per day              736.0    NaN      NaN  NaN        3.572758
# While working                733      2      Yes  579             NaN
# Fav genre                    736     16     Rock  188             NaN
# Exploratory                  736      2      Yes  525             NaN
# Foreign languages            732      2      Yes  404             NaN
# BPM                        629.0    NaN      NaN  NaN  1589948.344992
# Anxiety                    736.0    NaN      NaN  NaN        5.837636
# Depression                 736.0    NaN      NaN  NaN        4.796196
# Insomnia                   736.0    NaN      NaN  NaN        3.738451
# OCD                        736.0    NaN      NaN  NaN        2.637228
# ...

# %%
df_music_mh.to_csv('music_mh_limpa.csv', index=False)
